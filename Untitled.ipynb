# %%
import cv2

# %%
import numpy as np

# %%
bokeh0 = cv2.imread('img/IMG_8927.jpg')

# %%
bokeh1 = cv2.imread('img/IMG_8928.jpg')

# %%
import matplotlib.pyplot as plt

# %%
f = lambda img:plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
f(bokeh0)

# %%
f(bokeh1)

# %%
fimg =  np.fft.fftshift(np.fft.fft2(bokeh0))

# %%
fimg.shape
# Out:
# (1122, 1732, 3)

# %%
mag = 20*np.log(np.abs(fimg))

# %%
mag *= 255/mag.max()

# %%
magint = mag.astype(np.int64)

# %%
magint.shape
# Out:
# (1122, 1732, 3)

# %%
plt.imshow(magint[:, :, 1], cmap='gray')

# %%
fimg2.shape
# Out:
# (2067, 2947, 3)

# %%
fimg2 = np.fft.fftshift(np.fft.fft2(bokeh1))

# %%
mag2 = 20*np.log(np.abs(fimg))

# %%
mag2 *= 255/mag2.max()

# %%
magint2 = mag2.astype(np.int64)

# %%
plt.imshow(magint2[:, :, 1], cmap='gray')

# %%
cv2.Laplacian(bokeh0, cv2.CV_64F).var()
# Out:
# 33.35248194201202

# %%
cv2.Laplacian(bokeh1, cv2.CV_64F).var()
# Out:
# 148.29412614051023
