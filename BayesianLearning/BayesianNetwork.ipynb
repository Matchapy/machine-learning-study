# %%
import numpy as np
import sys
import matplotlib.pyplot as plt

# %%
data0 = np.random.normal(2, 0.5, size=5000)

# %%
data1 = np.random.normal(10, 0.8, size=5000)

# %%
plt.hist(data0, bins=30, alpha=0.9)
plt.hist(data1, bins=30, alpha=0.9)
plt.hist(data0*data1, bins=30, alpha=0.9)
# Out:
# (array([  1.,   1.,   0.,   2.,   2.,  10.,  23.,  34.,  65., 110., 182.,
#         262., 314., 404., 460., 502., 516., 485., 420., 391., 285., 185.,
#         136.,  87.,  45.,  29.,  28.,  14.,   3.,   4.]),
#  array([-2.46714979, -1.08804836,  0.29105308,  1.67015452,  3.04925596,
#          4.42835739,  5.80745883,  7.18656027,  8.56566171,  9.94476314,
#         11.32386458, 12.70296602, 14.08206745, 15.46116889, 16.84027033,
#         18.21937177, 19.5984732 , 20.97757464, 22.35667608, 23.73577752,
#         25.11487895, 26.49398039, 27.87308183, 29.25218327, 30.6312847 ,
#         32.01038614, 33.38948758, 34.76858902, 36.14769045, 37.52679189,
#         38.90589333]),
#  <a list of 30 Patch objects>)

# %%
plt
